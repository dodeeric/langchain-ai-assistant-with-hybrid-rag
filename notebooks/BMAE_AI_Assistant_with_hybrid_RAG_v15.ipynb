# %% [markdown]
# <a href="https://colab.research.google.com/github/dodeeric/langchain-ai-assistant-with-hybrid-rag/blob/main/BMAE_AI_Assistant_with_hybrid_RAG_v15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Assistant (LLM Chatbot) with Hybrid RAG -- With chat history
# v1: Hybrid RAG: keyword search (bm25) and semantic search (vector db)

# %% [markdown]
# v2: With memory: 1) Reformulate the question for RAG query (contextualize_q_prompt);  2) Add previous Q and A in prompt sent to the LLM.

# %% [markdown]
# v3: With PDF indexation

# %% [markdown]
# v5: With limited number of messages in chat history

# %%
# !pip install --upgrade --quiet jq bs4 langchain langchain-community langchain-openai langchain-chroma langchainhub rank_bm25 pypdf

import requests, json, jq, time, bs4
from bs4 import BeautifulSoup
from google.colab import userdata
from langchain import hub
from langchain_community.document_loaders import WebBaseLoader, JSONLoader, PyPDFLoader
from langchain_community.retrievers import BM25Retriever
from langchain.retrievers import EnsembleRetriever
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

OPENAI_API_KEY = userdata.get("OPENAI_API_KEY") # To access OpenAI LLM and embedding model via API
LANGCHAIN_API_KEY = userdata.get("LANGCHAIN_API_KEY") # To trace Langchain on Langsmith

# %env OPENAI_API_KEY = $OPENAI_API_KEY
# %env LANGCHAIN_API_KEY = $LANGCHAIN_API_KEY
# %env LANGCHAIN_TRACING_V2 = "true"

# import dotenv
# dotenv.load_dotenv()

# %% [markdown]
# ## Scrape

# %%
# Function to scrape the text and the metadata of a web page

def scrape_web_page(url):
    """
    Name: swp
    Scrape the text and the metadata of a web page
    Input: URL of the page
    Output: list of dictionaries with: url: url, metadata: metadata, text: text
    """

    #filter = "two-third last" # balat / irpa
    #filter = "media-body" # belgica / kbr
    filter = "hproduct commons-file-information-table" # commons / wikimedia: summary or description section

    # Get the page content
    loader = WebBaseLoader(
        web_paths=(url,),
        bs_kwargs=dict(
            parse_only=bs4.SoupStrainer(
                class_=(filter)
            )
        ),
    )
    text = loader.load()
    # Covert Document type into string type
    text = text[0].page_content

    # Get the metadata (open graph from Facebook, og:xxx)
    # Get the HTML code
    response = requests.get(url)
    # Transform the HTML code from a Response object type into a BeautifulSoup object type to be scraped by Beautiful Soup
    soup = BeautifulSoup(response.text, "html.parser")
    # Get the metadata fields
    metadata = {} # Empty dictionary
    # Find all the meta tags in the HTML
    meta_tags = soup.find_all("meta")
    # Loop through the meta tags
    for tag in meta_tags:
        property = tag.get("property")
        content = tag.get("content")
        # Add the property-content pair to the dictionary
        if property and content:
            metadata[property] = content

    # Build JSON string with: url: url, metadata: metadata, text: summary text
    # Create a dictionary
    page = {
        "url": url, # String
        "metadata": metadata, # Dictionary
        "text": text # String
    }

    return page # Dictionary

# %%
# METHOD 1: Scrape the URLs from a file and save the results in a JSON file

#ds1:

file_path = "/content/drive/MyDrive/colab/balat-urls-ds1"
#file_path = "/content/drive/MyDrive/colab/belgica-urls-ds1"
#file_path = "/content/drive/MyDrive/colab/commons-urls-ds1"

#ds2:
#file_path = "/content/drive/MyDrive/colab/balat-urls-ds2"
#file_path = "/content/drive/MyDrive/colab/commons-urls-ds2"

with open(f"{file_path}.txt", "r") as urls_file:
    items = []
    for line in urls_file:
        url = line.strip() # Remove spaces at the beginning and at the end of the string
        url = url.replace("\ufeff", "")  # Remove BOM (Byte order mark at the start of a text stream)
        item = scrape_web_page(url)
        print(item)
        items.append(item)
        #time.sleep(1)

# Save the Python list in a JSON file
# json.dump is designed to take the Python objects, not the already-JSONified string. Read docs.python.org/3/library/json.html.
with open(f"{file_path}-swp.json", "w") as json_file:
    json.dump(items, json_file) # That step replaces the accentuated characters (ex: é) by its utf8 codes (ex: \u00e9)
json_file.close()

# %%
# METHOD 2: For Belgica: Scrape the URLs automatically generated and save the results in a JSON file

file_path = "/content/drive/MyDrive/colab/belgica-"

items = []

number1 = 10000101
step = 100
number2 = number1 + step

for number in range(number1, number2):
    url = f"https://opac.kbr.be/LIBRARY/doc/SYRACUSE/{number}"
    #print(url)
    item = scrape_web_page(url)
    print(item)
    if item["text"]:
        items.append(item)
        print("saved")
    #time.sleep(1)

# Save the Python list in a JSON file
# json.dump is designed to take the Python objects, not the already-JSONified string. Read docs.python.org/3/library/json.html.
with open(f"{file_path}-{number1}-{number2}-swp.json", "w") as json_file:
    json.dump(items, json_file) # That step replaces the accentuated characters (ex: é) by its utf8 codes (ex: \u00e9)
json_file.close()

# %%
# METHOD 3: For Commons: Scrape the URLs from a Commons Category and save the results in a JSON file

file_path = "/content/drive/MyDrive/colab/commons-"

category = "Category:Engravings_by_Dodeeric"

items = []
href_old = ""

# Step 1: Load the HTML content from a webpage
url = f"https://commons.wikimedia.org/wiki/{category}"
response = requests.get(url)
html_content = response.text

# Step 2: Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Step 3: Find all URLs in <a> tags
urls = []
for link in soup.find_all('a'):
    href = link.get('href')
    if href:
        #print(href)
        if href.startswith("/wiki/File:") and href != href_old: # This test because all links are in double!
            urls.append(f"https://commons.wikimedia.org{href}")
            href_old = href

#print("***********************************************************")
# Print all found URLs
#for url in urls:
#    print(url)
#print("***********************************************************")

number_of_pages = len(urls)
print(f"Number of pages to scrape: {number_of_pages}")

i = 1
items = []
for url in urls:
    print(f"{i}/{number_of_pages}")
    url = url.replace("\ufeff", "")  # Remove BOM (Byte order mark at the start of a text stream)
    item = scrape_web_page(url)
    print(item)
    items.append(item)
    #time.sleep(1)
    i = i + 1

# Save the Python list in a JSON file
# json.dump is designed to take the Python objects, not the already-JSONified string. Read docs.python.org/3/library/json.html.
with open(f"{file_path}{category}-swp.json", "w") as json_file:
    json.dump(items, json_file) # That step replaces the accentuated characters (ex: é) by its utf8 codes (ex: \u00e9)
json_file.close()
# Out:
# Number of pages to scrape: 200
# 1/200
# {'url': 'https://commons.wikimedia.org/wiki/File:25e_anniversaire_de_l%27inauguration_du_roi_L%C3%A9opold_Ier,_Palais_de_la_Nation,_juillet_1856.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/25e_anniversaire_de_l%27inauguration_du_roi_L%C3%A9opold_Ier%2C_Palais_de_la_Nation%2C_juillet_1856.jpg/640px-25e_anniversaire_de_l%27inauguration_du_roi_L%C3%A9opold_Ier%2C_Palais_de_la_Nation%2C_juillet_1856.jpg', 'og:image:width': '640', 'og:image:height': '959', 'og:title': "File:25e anniversaire de l'inauguration du roi Léopold Ier, Palais de la Nation, juillet 1856.jpg - Wikimedia Commons", 'og:type': 'website'}, 'text': "\n\n\nDescription25e anniversaire de l'inauguration du roi Léopold Ier, Palais de la Nation, juillet 1856.jpg\n\nFrançais\xa0:  25e anniversaire de l’inauguration du roi Léopold\xa0Ier de Belgique, Palais de la Nation (Bruxelles), juillet 1856.\n\n\nDate\n\n1856\n\n\nSource\n\nLouis Hymans, 25e anniversaire de l’inauguration du Roi, les fêtes de juillet, les 21, 22 et 23 juillet 1856, Alexandre Jamar, Bruxelles, 1856, p.\xa028.\n\n\nAuthor\n\ndrawer: Henri Hendrickx (1817-1894).engraver: Henry Brown (1816-1870).\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 23 cm (9 in); width: 16 cm (6.2 in)dimensions QS:P2048,23U174728dimensions QS:P2049,16U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nVD  H HENDRICKX INV. Del\n\nSignature bottom right:  \n\nH. BROWN\n\n\nOriginal captionInfoFieldPlace de la Nation. Arrivée du Roi au banquet.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 2/200
# {'url': 'https://commons.wikimedia.org/wiki/File:25e_anniversaire_de_l%27inauguration_du_roi_L%C3%A9opold_Ier,_Place_royale,_juillet_1856_-_Hymans.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d1/25e_anniversaire_de_l%27inauguration_du_roi_L%C3%A9opold_Ier%2C_Place_royale%2C_juillet_1856_-_Hymans.jpg/640px-25e_anniversaire_de_l%27inauguration_du_roi_L%C3%A9opold_Ier%2C_Place_royale%2C_juillet_1856_-_Hymans.jpg', 'og:image:width': '640', 'og:image:height': '932', 'og:title': "File:25e anniversaire de l'inauguration du roi Léopold Ier, Place royale, juillet 1856 - Hymans.jpg - Wikimedia Commons", 'og:type': 'website'}, 'text': "\n\n\nDescription25e anniversaire de l'inauguration du roi Léopold Ier, Place royale, juillet 1856 - Hymans.jpg\n\nFrançais\xa0:  25e anniversaire de l’inauguration du roi Léopold\xa0Ier de Belgique, Place royale (Bruxelles), juillet 1856. — On peut lire en latin «\xa0LEOPOLDO PRIMO BELGARUM REGI\xa0» (Léopold Premier Roi Des Belges) et en chiffres romains «\xa0XXI JULI MDCCCXXXI\xa0» (21 juillet 1831).\n\n\nDate\n\n1856\n\n\nSource\n\nLouis Hymans, 25e anniversaire de l’inauguration du Roi, les fêtes de juillet, les 21, 22 et 23 juillet 1856, Alexandre Jamar, Bruxelles, 1856, p.\xa020.\n\n\nAuthor\n\ndrawer:\n\n\n\nHenri Hendrickx\n\xa0(1817–1894)\xa0\xa0 \xa0\n\n\nAlternative names\n\nL. Henri Hendrickx; Henri François Joseph Hendrickx; François Joseph Henri Henderickx\n\nDescription\nBelgian painter, drawer, illustrator, lithographer and printmaker\n\nDate of birth/death\n\n13 January 1817\xa0\n9 June 1894\xa0\n\nLocation of birth/death\n\nCity of Brussels\nSaint-Josse-ten-Noode\n\nWork location\n\nCity of Brussels (1832–1894)\xa0\n\nAuthority file\n\n: Q41302771\nVIAF:\u20099819958\nISNI:\u20090000000067037335\nULAN:\u2009500056485\nGND:\u20091049945638\nSELIBR:\u2009210392\n\n\n\ncreator QS:P170,Q41302771engraver:\n\n\n\nFrançois Pannemaker\n\xa0(1822–1900)\xa0\xa0\xa0 \xa0\n\n\nAlternative names\n\nAdolphe-François Pannemaker\n\nDescription\nBelgian engraver and visual artist\n\nDate of birth/death\n\n30 July 1822\xa0\n9 February 1900\xa0\n\nLocation of birth/death\n\nBrussels metropolitan area\nParis\n\nWork location\n\nCity of Brussels (1836–1843); Paris (1855–1900); City of Brussels (1845–1855); Paris (1843–1845); Paris (1861)\xa0\n\nAuthority file\n\n: Q3085503\nVIAF:\u2009288761467\nISNI:\u20090000000394340948\nULAN:\u2009500049561\nLCCN:\u2009nr90027015\nGND:\u2009129803677\nWorldCat\n\n\n\ncreator QS:P170,Q3085503\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 22 cm (8.6 in); width: 15 cm (5.9 in)dimensions QS:P2048,22U174728dimensions QS:P2049,15U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nHH. VD. (Monogram)\n\nSignature bottom center:  \n\nPANNEMAKER SC.\n\n\nOriginal captionInfoFieldArc de Triomphe de la Place Royale. Arrivée des princesses au Palais.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 3/200
# {'url': 'https://commons.wikimedia.org/wiki/File:25e_anniversaire_de_l%27inauguration_du_roi_L%C3%A9opold_Ier,_Place_royale,_juillet_1856.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/35/25e_anniversaire_de_l%27inauguration_du_roi_L%C3%A9opold_Ier%2C_Place_royale%2C_juillet_1856.jpg/640px-25e_anniversaire_de_l%27inauguration_du_roi_L%C3%A9opold_Ier%2C_Place_royale%2C_juillet_1856.jpg', 'og:image:width': '640', 'og:image:height': '826', 'og:title': "File:25e anniversaire de l'inauguration du roi Léopold Ier, Place royale, juillet 1856.jpg - Wikimedia Commons", 'og:type': 'website'}, 'text': "\n\n\nDescription25e anniversaire de l'inauguration du roi Léopold Ier, Place royale, juillet 1856.jpg\n\nFrançais\xa0:  25e anniversaire de l’inauguration du roi Léopold\xa0Ier de Belgique, Place royale (Bruxelles), juillet 1856.\n\n\nDate\n\n1856\n\n\nSource\n\nLouis Hymans, 25e anniversaire de l’inauguration du Roi, les fêtes de juillet, les 21, 22 et 23 juillet 1856, Alexandre Jamar, Bruxelles, 1856, p.\xa024.\n\n\nAuthor\n\ndrawer:\n\n\n\nHenri Hendrickx\n\xa0(1817–1894)\xa0\xa0 \xa0\n\n\nAlternative names\n\nL. Henri Hendrickx; Henri François Joseph Hendrickx; François Joseph Henri Henderickx\n\nDescription\nBelgian painter, drawer, illustrator, lithographer and printmaker\n\nDate of birth/death\n\n13 January 1817\xa0\n9 June 1894\xa0\n\nLocation of birth/death\n\nCity of Brussels\nSaint-Josse-ten-Noode\n\nWork location\n\nCity of Brussels (1832–1894)\xa0\n\nAuthority file\n\n: Q41302771\nVIAF:\u20099819958\nISNI:\u20090000000067037335\nULAN:\u2009500056485\nGND:\u20091049945638\nSELIBR:\u2009210392\n\n\n\ncreator QS:P170,Q41302771engraver:\n\n\n\nFrançois Pannemaker\n\xa0(1822–1900)\xa0\xa0\xa0 \xa0\n\n\nAlternative names\n\nAdolphe-François Pannemaker\n\nDescription\nBelgian engraver and visual artist\n\nDate of birth/death\n\n30 July 1822\xa0\n9 February 1900\xa0\n\nLocation of birth/death\n\nBrussels metropolitan area\nParis\n\nWork location\n\nCity of Brussels (1836–1843); Paris (1855–1900); City of Brussels (1845–1855); Paris (1843–1845); Paris (1861)\xa0\n\nAuthority file\n\n: Q3085503\nVIAF:\u2009288761467\nISNI:\u20090000000394340948\nULAN:\u2009500049561\nLCCN:\u2009nr90027015\nGND:\u2009129803677\nWorldCat\n\n\n\ncreator QS:P170,Q3085503\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 20 cm (7.8 in); width: 16 cm (6.2 in)dimensions QS:P2048,20U174728dimensions QS:P2049,16U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nHH. VD. (Monogram)\n\nSignature bottom right:  \n\nPANNEMAKER\n\n\nOriginal captionInfoFieldArc de triomphe de la Place royale. Arrivée du Roi.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 4/200
# {'url': 'https://commons.wikimedia.org/wiki/File:25e_anniversaire_de_l%E2%80%99inauguration_du_roi_L%C3%A9opold_Ier_-_Hymans.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/53/25e_anniversaire_de_l%E2%80%99inauguration_du_roi_L%C3%A9opold_Ier_-_Hymans.jpg/640px-25e_anniversaire_de_l%E2%80%99inauguration_du_roi_L%C3%A9opold_Ier_-_Hymans.jpg', 'og:image:width': '640', 'og:image:height': '947', 'og:title': 'File:25e anniversaire de l’inauguration du roi Léopold Ier - Hymans.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescription25e anniversaire de l’inauguration du roi Léopold Ier - Hymans.jpg\n\nFrançais\xa0:  25e anniversaire de l’inauguration du roi Léopold\xa0Ier de Belgique, Porte de Laeken, juillet 1856.\n\n\nDate\n\n1856\n\n\nSource\n\nLouis Hymans, 25e anniversaire de l’inauguration du Roi, les fêtes de juillet, les 21, 22 et 23 juillet 1856, Alexandre Jamar, Bruxelles, 1856, p.\xa032.\n\n\nAuthor\n\ndrawer: Henri Hendrickx (1817-1894).engraver: Henry Brown (1816-1870).\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 22 cm (8.6 in); width: 15 cm (5.9 in)dimensions QS:P2048,22U174728dimensions QS:P2049,15U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nH.HENDRICKX.INVT.ET.DEL.\n\nSignature bottom right:  \n\nH. BROWN SC\n\n\nOriginal captionInfoFieldArc de Triomphe de la Porte de Laeken. Arrivée du Roi.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 5/200
# {'url': 'https://commons.wikimedia.org/wiki/File:25e_anniversaire_de_l%E2%80%99inauguration_du_roi_L%C3%A9opold_Ier_le_22_juillet_1856.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/25e_anniversaire_de_l%E2%80%99inauguration_du_roi_L%C3%A9opold_Ier_le_22_juillet_1856.jpg/640px-25e_anniversaire_de_l%E2%80%99inauguration_du_roi_L%C3%A9opold_Ier_le_22_juillet_1856.jpg', 'og:image:width': '640', 'og:image:height': '436', 'og:title': 'File:25e anniversaire de l’inauguration du roi Léopold Ier le 22 juillet 1856.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescription25e anniversaire de l’inauguration du roi Léopold Ier le 22 juillet 1856.jpg\n\nFrançais\xa0:  25e anniversaire de l’inauguration du roi Léopold\xa0Ier de Belgique, Palais royal (Bruxelles), le 22 juillet 1856. — La revue a lieux en présence du Roi, du duc de Brabant, du comte de Flandre, du duc Ernest\xa0Ier de Saxe-Cobourg-Gotha et du prince George de la Saxe royale, ainsi que d’un nombreux état-major. De nombreuses légions de la garde civique et régiments de l’armée défilent.\n\n\nDate\n\n1856\n\n\nSource\n\nLouis Hymans, 25e anniversaire de l’inauguration du Roi, les fêtes de juillet, les 21, 22 et 23 juillet 1856, Alexandre Jamar, Bruxelles (Belgium), 1856, p.\xa068.\n\n\nAuthor\n\nUnknown authorUnknown author\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 17 cm (6.6 in); width: 24 cm (9.4 in)dimensions QS:P2048,17U174728dimensions QS:P2049,24U174728\n\nOriginal captionInfoFieldRevue de la garde civique et de l’armée.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 6/200
# {'url': 'https://commons.wikimedia.org/wiki/File:25e_anniversaire_de_l%E2%80%99inauguration_du_roi_L%C3%A9opold_Ier.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c7/25e_anniversaire_de_l%E2%80%99inauguration_du_roi_L%C3%A9opold_Ier.jpg/640px-25e_anniversaire_de_l%E2%80%99inauguration_du_roi_L%C3%A9opold_Ier.jpg', 'og:image:width': '640', 'og:image:height': '972', 'og:title': 'File:25e anniversaire de l’inauguration du roi Léopold Ier.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescription25e anniversaire de l’inauguration du roi Léopold Ier.jpg\n\nFrançais\xa0:  25e anniversaire de l’inauguration du roi Léopold\xa0Ier de Belgique, Place royale (Bruxelles), juillet 1856. — À l’avant plan, on aperçoit à cheval, le Roi et ses deux fils\xa0: Léopold, duc de Brabant, et Philippe, comte de Flandre.\n\n\nDate\n\n1856\n\n\nSource\n\nLouis Hymans, 25e anniversaire de l’inauguration du Roi, les fêtes de juillet, les 21, 22 et 23 juillet 1856, Alexandre Jamar, Bruxelles (Belgium), 1856, p.\xa036.\n\n\nAuthor\n\ndrawer:\n\n\n\nHenri Hendrickx\n\xa0(1817–1894)\xa0\xa0 \xa0\n\n\nAlternative names\n\nL. Henri Hendrickx; Henri François Joseph Hendrickx; François Joseph Henri Henderickx\n\nDescription\nBelgian painter, drawer, illustrator, lithographer and printmaker\n\nDate of birth/death\n\n13 January 1817\xa0\n9 June 1894\xa0\n\nLocation of birth/death\n\nCity of Brussels\nSaint-Josse-ten-Noode\n\nWork location\n\nCity of Brussels (1832–1894)\xa0\n\nAuthority file\n\n: Q41302771\nVIAF:\u20099819958\nISNI:\u20090000000067037335\nULAN:\u2009500056485\nGND:\u20091049945638\nSELIBR:\u2009210392\n\n\n\ncreator QS:P170,Q41302771engraver:\n\n\n\nFrançois Pannemaker\n\xa0(1822–1900)\xa0\xa0\xa0 \xa0\n\n\nAlternative names\n\nAdolphe-François Pannemaker\n\nDescription\nBelgian engraver and visual artist\n\nDate of birth/death\n\n30 July 1822\xa0\n9 February 1900\xa0\n\nLocation of birth/death\n\nBrussels metropolitan area\nParis\n\nWork location\n\nCity of Brussels (1836–1843); Paris (1855–1900); City of Brussels (1845–1855); Paris (1843–1845); Paris (1861)\xa0\n\nAuthority file\n\n: Q3085503\nVIAF:\u2009288761467\nISNI:\u20090000000394340948\nULAN:\u2009500049561\nLCCN:\u2009nr90027015\nGND:\u2009129803677\nWorldCat\n\n\n\ncreator QS:P170,Q3085503\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 24 cm (9.4 in); width: 16 cm (6.2 in)dimensions QS:P2048,24U174728dimensions QS:P2049,16U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nHH VD (Monograms)\n\nSignature bottom right:  \n\nPANNEMAKER\n\n\nOriginal captionInfoFieldArc de triomphe de la Place royale. Réception du Roi par les anciens membres du Congrès.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 7/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Accueil_de_la_princesse_St%C3%A9phanie_de_Belgique_par_le_bourgmestre_lors_de_son_mariage_avec_l%27archiduc_Rodolphe_d%27Autriche_le_10_mai_1881_-_The_Graphic.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/06/Accueil_de_la_princesse_St%C3%A9phanie_de_Belgique_par_le_bourgmestre_lors_de_son_mariage_avec_l%27archiduc_Rodolphe_d%27Autriche_le_10_mai_1881_-_The_Graphic.jpg/640px-Accueil_de_la_princesse_St%C3%A9phanie_de_Belgique_par_le_bourgmestre_lors_de_son_mariage_avec_l%27archiduc_Rodolphe_d%27Autriche_le_10_mai_1881_-_The_Graphic.jpg', 'og:image:width': '640', 'og:image:height': '474', 'og:title': "File:Accueil de la princesse Stéphanie de Belgique par le bourgmestre lors de son mariage avec l'archiduc Rodolphe d'Autriche le 10 mai 1881 - The Graphic.jpg - Wikimedia Commons", 'og:type': 'website'}, 'text': '\n\n\n\nArtist\n\n\nsigned (bottom left)\n\n\nAuthor\n\n\nThe Graphic\n\n\nDescription\n\n\nEnglish:  The Royal Wedding in Austria. Illustration for The Graphic, 21 May 1881. reference\nPrincess Stéphanie of Belgium is welcomed by the mayor during her marriage to Archduke Rudolph of Austria, Vienna (Austria), 10 May 1881.\nFrançais\xa0:  Accueil de la princesse Stéphanie de Belgique par le bourgmestre lors de son mariage avec l’archiduc Rodolphe d’Autriche, Vienne (Autriche), le 10 mai 1881.\nNederlands:  Prinses Stefanie van België wordt verwelkomd door de burgemeester tijdens haar huwelijk met aartshertog Rudolf van Oostenrijk, Wenen (Oostenrijk), 10 mei 1881.\n\n\nDate\n\n21 May 1881date QS:P571,+1881-05-21T00:00:00Z/11\n\n\nSource/Photographer\n\nThe Graphic (United Kingdom), 21 May 1881, p.\xa0492.\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 17 cm (6.6 in); width: 23 cm (9 in)dimensions QS:P2048,17U174728dimensions QS:P2049,23U174728\n\nInscriptionsInfoField\n\nOriginal captionInfoFieldThe royal wedding in Austria. State entry of the Princess Stéphanie into Vienna. The burgomaster presenting the address of welcome.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 8/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Accueil_de_la_princesse_St%C3%A9phanie_de_Belgique_par_le_bourgmestre_lors_de_son_mariage_avec_l%E2%80%99archiduc_Rodolphe_d%E2%80%99Autriche_le_10_mai_1881.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Accueil_de_la_princesse_St%C3%A9phanie_de_Belgique_par_le_bourgmestre_lors_de_son_mariage_avec_l%E2%80%99archiduc_Rodolphe_d%E2%80%99Autriche_le_10_mai_1881.jpg/640px-Accueil_de_la_princesse_St%C3%A9phanie_de_Belgique_par_le_bourgmestre_lors_de_son_mariage_avec_l%E2%80%99archiduc_Rodolphe_d%E2%80%99Autriche_le_10_mai_1881.jpg', 'og:image:width': '640', 'og:image:height': '451', 'og:title': 'File:Accueil de la princesse Stéphanie de Belgique par le bourgmestre lors de son mariage avec l’archiduc Rodolphe d’Autriche le 10 mai 1881.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionAccueil de la princesse Stéphanie de Belgique par le bourgmestre lors de son mariage avec l’archiduc Rodolphe d’Autriche le 10 mai 1881.jpg\n\nEnglish:  Princess Stéphanie of Belgium is welcomed by the mayor during her marriage to Archduke Rudolph of Austria, Vienna (Austria), 10 May 1881.\nFrançais\xa0:  Accueil de la princesse Stéphanie de Belgique par le bourgmestre lors de son mariage avec l’archiduc Rodolphe d’Autriche, Vienne (Autriche), le 10 mai 1881.\nNederlands:  Prinses Stefanie van België wordt verwelkomd door de burgemeester tijdens haar huwelijk met aartshertog Rudolf van Oostenrijk, Wenen (Oostenrijk), 10 mei 1881.\n\n\nDate\n\n1881\n\n\nSource\n\nLe Monde illustré (France), 21 May 1881, p.\xa0344-345.\n\n\nAuthor\n\ndrawer: \n\n\n\nFrédéric de Haenen\n\xa0(1853–1929)\xa0\xa0\xa0 \xa0\n\n\n\n\n\nAlternative names\n\nF. de Haenen\n\nDescription\nDutch-French painter and drawer\n\nDate of birth/death\n\n1853\xa0\n1 June 1929\xa0\n\nLocation of birth/death\n\nUtrecht\nÎle-de-Bréhat\n\nWork period\n1896\xa0\n\nAuthority file\n\n: Q18115931\nVIAF:\u200976584192\nISNI:\u20090000000002707908\nLCCN:\u2009no2015080533\nGND:\u20091161044183\nSUDOC:\u2009165026472\nWorldCat\n\n\n\ncreator QS:P170,Q18115931\nengraver: \n\n\n\nAuguste-Louis Lepère\n\xa0(1849–1918)\xa0\xa0\xa0 \xa0\n\n\n\n\n\nDescription\nFrench painter, engraver, illustrator, graphic artist, drawer and visual artist\n\nDate of birth/death\n\n30 November 1849\xa0\n20 November 1918 / 20 November 1919 / 1918\xa0\n\nLocation of birth/death\n\nParis\nDomme\n\nWork period\n1869\xa0–1918\xa0\n\nWork location\n\nNetherlands (1901); Amsterdam (1901)\xa0\n\nAuthority file\n\n: Q2871286\nVIAF:\u200959121898\nISNI:\u20090000000109054775\nULAN:\u2009500018893\nLCCN:\u2009n82240734\nOpen Library:\u2009OL2421891A\nWorldCat\n\n\n\ncreator QS:P170,Q2871286\nAfter (sketch):\n\n\n\nWilhelm Gause\n\xa0(1853–1916)\xa0\xa0 \xa0\n\n\n\n\n\nAlternative names\n\ngause wilhelm; wilhelm gause; w. gause\n\nDescription\nGerman-Austrian painter and illustrator\n\nDate of birth/death\n\n27 March 1853\xa0\n13 June 1916\xa0\n\nLocation of birth/death\n\nKrefeld\nStein an der Donau\n\nAuthority file\n\n: Q16853517\nVIAF:\u2009229494\nISNI:\u20090000000066560781\nULAN:\u2009500045274\nGND:\u2009123031427\nSUDOC:\u2009073391662\n\n\n\ncreator QS:P170,Q16853517\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 31 cm (12.2 in); width: 45 cm (17.7 in)dimensions QS:P2048,31U174728dimensions QS:P2049,45U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nHaenen / W Gause (Not visible on the scan)\n\nSignature bottom right:  \n\nA LEPERE (Not visible on the scan)\n\n\nOriginal captionInfoFieldAutriche-Hongrie. Le mariage du prince Rodolphe et de la princesse Stéphanie. Entrée solennelle à Vienne. Le bourgmestre reçoit la princesse à l’entrée du faubourg de la Wieden, près du pont Élisabeth. Dessin de M. de Haenen, d’après le croquis de M. Gause, notre correspondant spécial.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 9/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Anniversaire_de_la_mort_d%E2%80%99Adolphe_Thiers.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Anniversaire_de_la_mort_d%E2%80%99Adolphe_Thiers.jpg/640px-Anniversaire_de_la_mort_d%E2%80%99Adolphe_Thiers.jpg', 'og:image:width': '640', 'og:image:height': '438', 'og:title': 'File:Anniversaire de la mort d’Adolphe Thiers.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionAnniversaire de la mort d’Adolphe Thiers.jpg\n\nFrançais\xa0:  Anniversaire de la mort d’Adolphe Thiers.\n\n\nDate\n\n1878\n\n\nSource\n\nLe Monde illustré, 7 septembre 1878, p.\xa0156.\n\n\nAuthor\n\ndrawer:\n\n\n\nPaul Kauffmann\n\xa0(1849–1940)\xa0\xa0\xa0 \xa0\n\n\nAlternative names\n\nPaul Kauffmann, Paul Adolphe Kauffmann\n\nDescription\nFrench illustrator, painter, watercolorist, drawer, graphic artist and commercial artist\n\nDate of birth/death\n\n8 June 1849 / 8 July 1849\xa0\n20 February 1940\xa0\n\nLocation of birth/death\n\nBelfort\nGrimault\n\nAuthority file\n\n: Q3370424\nVIAF:\u200968867201\nISNI:\u20090000000083911328\nLCCN:\u2009nr2002028326\nGND:\u20091048596583\nSUDOC:\u2009050733583\nWorldCat\n\n\n\ncreator QS:P170,Q3370424\nengraver: Régnier-Barbant\n\n\n'}
# 10/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Antoine_Clesse_-_Po%C3%A8te_et_chansonnier_belge.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Antoine_Clesse_-_Po%C3%A8te_et_chansonnier_belge.jpg/640px-Antoine_Clesse_-_Po%C3%A8te_et_chansonnier_belge.jpg', 'og:image:width': '640', 'og:image:height': '777', 'og:title': 'File:Antoine Clesse - Poète et chansonnier belge.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionAntoine Clesse - Poète et chansonnier belge.jpg\n\nFrançais\xa0:  Antoine Clesse (1816-1889), poète et chansonnier belge.\n\n\nDate\n\n1880\n\n\nSource\n\nL’Illustration nationale (Belgium), 30 May 1880, p.\xa08.\n\n\nAuthor\n\nengraver: M. Weber.\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 13 cm (5.1 in); width: 11 cm (4.3 in)dimensions QS:P2048,13U174728dimensions QS:P2049,11U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nMWEBER Sc\n\n\nOriginal captionInfoFieldAntoine Clesse\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 11/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Archiduc_Rodolphe,_prince_h%C3%A9ritier_d%27Autriche_et_de_Hongrie.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Archiduc_Rodolphe%2C_prince_h%C3%A9ritier_d%27Autriche_et_de_Hongrie.jpg/640px-Archiduc_Rodolphe%2C_prince_h%C3%A9ritier_d%27Autriche_et_de_Hongrie.jpg', 'og:image:width': '640', 'og:image:height': '890', 'og:title': "File:Archiduc Rodolphe, prince héritier d'Autriche et de Hongrie.jpg - Wikimedia Commons", 'og:type': 'website'}, 'text': "\n\n\nDescriptionArchiduc Rodolphe, prince héritier d'Autriche et de Hongrie.jpg\n\nFrançais\xa0:  S.A.I. et R. l’archiduc Rodolphe, prince héritier d’Autriche et de Hongrie. — Portrait publié à l’occasion de son décès.\n\n\nDate\n\n1889\n\n\nSource\n\nLe Journal illustré (France), 10 February 1889, p.\xa045.\n\n\nAuthor\n\ndrawer: \n\n\n\nHenri Meyer\n\xa0(1841–1899)\xa0\xa0\xa0 \xa0\n\n\nAlternative names\n\nReyem; Henri Mayer; Jacques Meyer\n\nDescription\nFrench caricaturist and illustrator\n\nDate of birth/death\n\n6 March 1841\xa0\n18 July 1899\xa0\n\nLocation of birth/death\n\nMulhouse\nThiais\n\nAuthority file\n\n: Q3131638\nVIAF:\u200996603524\nISNI:\u20090000000110574911\nULAN:\u2009500124916\nLCCN:\u2009no2016080312\nNLA:\u200967444760\nWorldCat\n\n\n\ncreator QS:P170,Q3131638\nengraver: Narcisse Navellier.\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 19 cm (7.4 in); width: 14 cm (5.5 in)dimensions QS:P2048,19U174728dimensions QS:P2049,14U174728\n\nInscriptionsInfoFieldUnsigned\n\nOriginal captionInfoFieldLa famille impériale d’Autriche. L’archiduc Rodolphe. Prince héritier décédé. Dessins de Henri Meyer, d’après les photographies communiquées par M. Nilsson, éditeur. Gravure de Navellier. Voir l’article, page\xa042.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 12/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Archiduchesse_%C3%89lisabeth-Marie_d%27Autriche.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3b/Archiduchesse_%C3%89lisabeth-Marie_d%27Autriche.jpg/640px-Archiduchesse_%C3%89lisabeth-Marie_d%27Autriche.jpg', 'og:image:width': '640', 'og:image:height': '677', 'og:title': "File:Archiduchesse Élisabeth-Marie d'Autriche.jpg - Wikimedia Commons", 'og:type': 'website'}, 'text': "\n\n\nDescriptionArchiduchesse Élisabeth-Marie d'Autriche.jpg\n\nFrançais\xa0:  S.A.I. et R. l’archiduchesse Élisabeth-Marie d’Autriche, fille de Stéphanie de Belgique et de Rodolphe d’Autriche. — Portrait publié à l’occasion du décès de Rodolphe, son père. La fille unique de Stéphanie et Rodolphe a environ 5\xa0ans sur cette gravure.\n\n\nDate\n\n1889\n\n\nSource\n\nLe Journal illustré (France), 10 February 1889, p.\xa044.\n\n\nAuthor\n\ndrawer: \n\n\n\nHenri Meyer\n\xa0(1841–1899)\xa0\xa0\xa0 \xa0\n\n\nAlternative names\n\nReyem; Henri Mayer; Jacques Meyer\n\nDescription\nFrench caricaturist and illustrator\n\nDate of birth/death\n\n6 March 1841\xa0\n18 July 1899\xa0\n\nLocation of birth/death\n\nMulhouse\nThiais\n\nAuthority file\n\n: Q3131638\nVIAF:\u200996603524\nISNI:\u20090000000110574911\nULAN:\u2009500124916\nLCCN:\u2009no2016080312\nNLA:\u200967444760\nWorldCat\n\n\n\ncreator QS:P170,Q3131638\nengraver: Narcisse Navellier.\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 11 cm (4.3 in); width: 10 cm (3.9 in)dimensions QS:P2048,11U174728dimensions QS:P2049,10U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nH.MEYER\n\nSignature bottom right:  \n\nN.N.Sc\n\n\nOriginal captionInfoFieldLa famille impériale d’Autriche. La princesse Élisabeth. Fille du prince Rodolphe. Dessins de Henri Meyer, d’après les photographies communiquées par M. Nilsson, éditeur. Gravure de Navellier. Voir l’article, page\xa042.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 13/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Arriv%C3%A9e_de_L%C3%A9opold_et_Marie-Henriette_%C3%A0_Spa.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Arriv%C3%A9e_de_L%C3%A9opold_et_Marie-Henriette_%C3%A0_Spa.jpg/640px-Arriv%C3%A9e_de_L%C3%A9opold_et_Marie-Henriette_%C3%A0_Spa.jpg', 'og:image:width': '640', 'og:image:height': '429', 'og:title': 'File:Arrivée de Léopold et Marie-Henriette à Spa.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionArrivée de Léopold et Marie-Henriette à Spa.jpg\n\nEnglish:  Arrival of Leopold of Belgium and Marie Henriette in Spa (Belgium).\nFrançais\xa0:  Arrivée de Léopold de Belgique et Marie-Henriette à Spa (Belgique). — La reine Marie-Henriette séjournera très souvent dans la ville thermale de Spa, où elle finira par s’installer définitivement en 1895, à l’Hôtel du Midi (actuelle «\xa0Villa royale\xa0»). Elle y décédera en 1902.\nNederlands:  Aankomst van Leopold van Belgïe en Marie Henriëtte in Spa (België).\n\n\nDate\n\n1856\n\n\nSource\n\nThe Illustrated London News (United Kingdom), 16 August 1856.\n\n\nAuthor\n\nUnknown authorUnknown author\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 16 cm (6.2 in); width: 24 cm (9.4 in)dimensions QS:P2048,16U174728dimensions QS:P2049,24U174728\n\nInscriptionsInfoFieldUnsigned\n\nOriginal captionInfoFieldSpa, arrival of the Duke and Duchess of Brabant.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 14/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Arriv%C3%A9e_de_L%C3%A9opold_Ier_%C3%A0_la_fronti%C3%A8re_belge_le_17_juillet_1831.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/25/Arriv%C3%A9e_de_L%C3%A9opold_Ier_%C3%A0_la_fronti%C3%A8re_belge_le_17_juillet_1831.jpg/640px-Arriv%C3%A9e_de_L%C3%A9opold_Ier_%C3%A0_la_fronti%C3%A8re_belge_le_17_juillet_1831.jpg', 'og:image:width': '640', 'og:image:height': '385', 'og:title': 'File:Arrivée de Léopold Ier à la frontière belge le 17 juillet 1831.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionArrivée de Léopold Ier à la frontière belge le 17 juillet 1831.jpg\n\nFrançais\xa0:  Arrivée de Léopold\xa0Ier à la frontière belge, La Panne, le 17 juillet 1831. — Le 16 juillet 1831, le prince Léopold embarque à Douvres sur le yacht Crusader, à destination du continent. Il est accueilli à Calais par le Premier ministre de France à Bruxelles. Le 17 juillet 1831, il arrive en calèche à La Panne, par la plage de Dunkerque. Il est solennellement accueilli, avant de continuer le voyage vers Laeken, en passant par Furnes, Ostende, Bruges, Gand et Alost. Le monument sur l’esplanade Léopold\xa0Ier à La Panne symbolise la porte par laquelle le premier roi des Belges est entré en Belgique.\n\n\nDate\n\n1868\n\n\nSource\n\nThéodore Juste, Histoire de Belgique, tome\xa0III, Bruylant-Christophe, Bruxelles, 1868, p.\xa0154.\n\n\nAuthor\n\nUnknown authorUnknown author\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 10 cm (3.9 in); width: 17 cm (6.6 in)dimensions QS:P2048,10U174728dimensions QS:P2049,17U174728\n\nInscriptionsInfoFieldUnsigned\n\nOriginal captionInfoFieldRéception du prince Léopold à la frontière belge (17 juillet 1831).\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 15/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865_-_Smeeton.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865_-_Smeeton.jpg/640px-Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865_-_Smeeton.jpg', 'og:image:width': '640', 'og:image:height': '442', 'og:title': 'File:Arrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865 - Smeeton.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': "\n\n\nDescriptionArrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865 - Smeeton.jpg\n\nFrançais\xa0:  Arrivée de Léopold\xa0II devant le théâtre de la Monnaie le jour de son avènement, Bruxelles, le 17 décembre 1865.\n\n\nDate\n\n1880\n\n\nSource\n\nL’Illustration nationale (Belgium), 30 April 1880, p.\xa04.\n\n\nAuthor\n\nengraver: Joseph Smeeton, Auguste Tilly.\n\nAfter (photo):\n\n\n\nGhémar Frères studio\n\xa0(fl. 1882)\xa0\xa0 \xa0\n\n\nAlternative names\n\nGhemar Frères Atelier de Photographie\n\nDescription\nBelgianGhémar Frères, Photographes du Roi, 27, Rue de l'Ecuyer, Bruxelles.\nEnglish:  The photo studio of the two brothers Ghémar was the most renowned Belgian photostudio in the period 1855–1870. \nIn 1855 Louis Ghémar (1820–1873)[1] opened a photostudio in Brussels, next to the studio of Jules Géruzet. \nIn the beginning Louis Ghémar worked together with Robert Sévérin. Sévérin took the photos and Ghémar made the retouches and eventually colours the photos. But Sévérin left Brussels and was replaced by Louis Ghémars halfbrother, Léon Auverlaux. From then on the name of the studio was changed to Ghémar Frères. \n\nLouis Ghémar died in 1873 but the studio kept the name Ghémar Frères until 1894 when Géruzet takes over the studio, including all the negatives of Ghémar.[2]\n\nWork period\nbetween 1855 and 1894date QS:P,+1850-00-00T00:00:00Z/7,P1319,+1855-00-00T00:00:00Z/9,P1326,+1894-00-00T00:00:00Z/9\n\nWork location\n\nCity of Brussels\n\nAuthority file\n\n: Q21557453\nVIAF:\u2009158671009\nLCCN:\u2009no2007070950\nBNF:\u200915346099j\nRKD:\u2009417254\nWorldCat\n\n\n\ncreator QS:P170,Q21557453\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 22 cm (8.6 in); width: 32 cm (12.5 in)dimensions QS:P2048,22U174728dimensions QS:P2049,32U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nSMEETON TILLY\n\n\nOriginal captionInfoFieldEntrée de Léopold\xa0II à Bruxelles le 17 décembre 1865. Vue prise de la place de la Monnaie.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 16/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865_-_Verdyen_-_Rod.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865_-_Verdyen_-_Rod.jpg/640px-Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865_-_Verdyen_-_Rod.jpg', 'og:image:width': '640', 'og:image:height': '380', 'og:title': 'File:Arrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865 - Verdyen - Rod.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': "\n\n\nDescriptionArrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865 - Verdyen - Rod.jpg\n\nFrançais\xa0:  Arrivée de Léopold\xa0II devant le théâtre de la Monnaie le jour de son avènement, Bruxelles, le 17 décembre 1865.\n\n\nDate\n\n1888\n\n\nSource\n\nThéodore Juste, Histoire de Belgique, tome\xa0III, Bruylant-Christophe, Bruxelles, 1888, p.\xa0317.\n\n\nAuthor\n\ndrawer:\n\n\n\nEugène Verdyen\n\xa0(1836–1903)\xa0\xa0 \xa0\n\n\nAlternative names\n\nEugène Verdijen\n\nDescription\nBelgian painter and drawer\n\nDate of birth/death\n\n29 August 1836\xa0\n17 June 1903\xa0\n\nLocation of birth/death\n\nLiège\nCity of Brussels\n\nAuthority file\n\n: Q26235979\nVIAF:\u200996356968\nULAN:\u2009500092395\nLCCN:\u2009no2017155663\nGND:\u20091137839317\nSUDOC:\u2009203177894\nWorldCat\n\n\n\ncreator QS:P170,Q26235979\nengraver: Ch. Rod.\n\nAfter (photo):\n\n\n\nGhémar Frères studio\n\xa0(fl. 1882)\xa0\xa0 \xa0\n\n\nAlternative names\n\nGhemar Frères Atelier de Photographie\n\nDescription\nBelgianGhémar Frères, Photographes du Roi, 27, Rue de l'Ecuyer, Bruxelles.\nEnglish:  The photo studio of the two brothers Ghémar was the most renowned Belgian photostudio in the period 1855–1870. \nIn 1855 Louis Ghémar (1820–1873)[1] opened a photostudio in Brussels, next to the studio of Jules Géruzet. \nIn the beginning Louis Ghémar worked together with Robert Sévérin. Sévérin took the photos and Ghémar made the retouches and eventually colours the photos. But Sévérin left Brussels and was replaced by Louis Ghémars halfbrother, Léon Auverlaux. From then on the name of the studio was changed to Ghémar Frères. \n\nLouis Ghémar died in 1873 but the studio kept the name Ghémar Frères until 1894 when Géruzet takes over the studio, including all the negatives of Ghémar.[2]\n\nWork period\nbetween 1855 and 1894date QS:P,+1850-00-00T00:00:00Z/7,P1319,+1855-00-00T00:00:00Z/9,P1326,+1894-00-00T00:00:00Z/9\n\nWork location\n\nCity of Brussels\n\nAuthority file\n\n: Q21557453\nVIAF:\u2009158671009\nLCCN:\u2009no2007070950\nBNF:\u200915346099j\nRKD:\u2009417254\nWorldCat\n\n\n\ncreator QS:P170,Q21557453\n\n\nOther versions\n\n\n\n\nFile:Arrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865 - Verdyen.jpg\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 7 cm (2.7 in); width: 11 cm (4.3 in)dimensions QS:P2048,7U174728dimensions QS:P2049,11U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nVERDYEN\n\nSignature bottom right:  \n\nCH.ROD\n\n\nOriginal captionInfoFieldEntrée solennelle à Bruxelles de Léopold\xa0II (17 décembre 1865).\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 17/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865_-_Verdyen.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e0/Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865_-_Verdyen.jpg/640px-Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865_-_Verdyen.jpg', 'og:image:width': '640', 'og:image:height': '369', 'og:title': 'File:Arrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865 - Verdyen.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': "\n\n\nDescriptionArrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865 - Verdyen.jpg\n\nFrançais\xa0:  Arrivée de Léopold\xa0II devant le théâtre de la Monnaie le jour de son avènement, Bruxelles, le 17 décembre 1865.\n\n\nDate\n\n1888\n\n\nSource\n\nThéodore Juste, Histoire de Belgique, tome\xa0III, Bruylant-Christophe, Bruxelles, 1888, p.\xa0317.\n\n\nAuthor\n\ndrawer:\n\n\n\nEugène Verdyen\n\xa0(1836–1903)\xa0\xa0 \xa0\n\n\nAlternative names\n\nEugène Verdijen\n\nDescription\nBelgian painter and drawer\n\nDate of birth/death\n\n29 August 1836\xa0\n17 June 1903\xa0\n\nLocation of birth/death\n\nLiège\nCity of Brussels\n\nAuthority file\n\n: Q26235979\nVIAF:\u200996356968\nULAN:\u2009500092395\nLCCN:\u2009no2017155663\nGND:\u20091137839317\nSUDOC:\u2009203177894\nWorldCat\n\n\n\ncreator QS:P170,Q26235979\nengraver: Ch. Rod.\n\nAfter (photo):\n\n\n\nGhémar Frères studio\n\xa0(fl. 1882)\xa0\xa0 \xa0\n\n\nAlternative names\n\nGhemar Frères Atelier de Photographie\n\nDescription\nBelgianGhémar Frères, Photographes du Roi, 27, Rue de l'Ecuyer, Bruxelles.\nEnglish:  The photo studio of the two brothers Ghémar was the most renowned Belgian photostudio in the period 1855–1870. \nIn 1855 Louis Ghémar (1820–1873)[1] opened a photostudio in Brussels, next to the studio of Jules Géruzet. \nIn the beginning Louis Ghémar worked together with Robert Sévérin. Sévérin took the photos and Ghémar made the retouches and eventually colours the photos. But Sévérin left Brussels and was replaced by Louis Ghémars halfbrother, Léon Auverlaux. From then on the name of the studio was changed to Ghémar Frères. \n\nLouis Ghémar died in 1873 but the studio kept the name Ghémar Frères until 1894 when Géruzet takes over the studio, including all the negatives of Ghémar.[2]\n\nWork period\nbetween 1855 and 1894date QS:P,+1850-00-00T00:00:00Z/7,P1319,+1855-00-00T00:00:00Z/9,P1326,+1894-00-00T00:00:00Z/9\n\nWork location\n\nCity of Brussels\n\nAuthority file\n\n: Q21557453\nVIAF:\u2009158671009\nLCCN:\u2009no2007070950\nBNF:\u200915346099j\nRKD:\u2009417254\nWorldCat\n\n\n\ncreator QS:P170,Q21557453\n\n\nOther versions\n\n\n\n\nFile:Arrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865 - Verdyen - Rod.jpg\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 7 cm (2.7 in); width: 11 cm (4.3 in)dimensions QS:P2048,7U174728dimensions QS:P2049,11U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nVERDYEN\n\nSignature bottom right:  \n\nCH.ROD\n\n\nOriginal captionInfoFieldEntrée solennelle à Bruxelles de Léopold\xa0II (17 décembre 1865).\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 18/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865.jpg/640px-Arriv%C3%A9e_de_L%C3%A9opold_II_devant_le_th%C3%A9%C3%A2tre_de_la_Monnaie_le_jour_de_son_av%C3%A8nement_le_17_d%C3%A9cembre_1865.jpg', 'og:image:width': '640', 'og:image:height': '439', 'og:title': 'File:Arrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': "\n\n\nDescriptionArrivée de Léopold II devant le théâtre de la Monnaie le jour de son avènement le 17 décembre 1865.jpg\n\nFrançais\xa0:  Arrivée de Léopold\xa0II devant le théâtre de la Monnaie le jour de son avènement, Bruxelles, le 17 décembre 1865.\n\n\nDate\n\n1880\n\n\nSource\n\nL’Illustration nationale (Belgium), 30 April 1880, p.\xa04.\n\n\nAuthor\n\nengraver: Joseph Smeeton, Auguste Tilly.\n\nAfter (photo): \n\n\n\nGhémar Frères studio\n\xa0(fl. 1882)\xa0\xa0 \xa0\n\n\nAlternative names\n\nGhemar Frères Atelier de Photographie\n\nDescription\nBelgianGhémar Frères, Photographes du Roi, 27, Rue de l'Ecuyer, Bruxelles.\nEnglish:  The photo studio of the two brothers Ghémar was the most renowned Belgian photostudio in the period 1855–1870. \nIn 1855 Louis Ghémar (1820–1873)[1] opened a photostudio in Brussels, next to the studio of Jules Géruzet. \nIn the beginning Louis Ghémar worked together with Robert Sévérin. Sévérin took the photos and Ghémar made the retouches and eventually colours the photos. But Sévérin left Brussels and was replaced by Louis Ghémars halfbrother, Léon Auverlaux. From then on the name of the studio was changed to Ghémar Frères. \n\nLouis Ghémar died in 1873 but the studio kept the name Ghémar Frères until 1894 when Géruzet takes over the studio, including all the negatives of Ghémar.[2]\n\nWork period\nbetween 1855 and 1894date QS:P,+1850-00-00T00:00:00Z/7,P1319,+1855-00-00T00:00:00Z/9,P1326,+1894-00-00T00:00:00Z/9\n\nWork location\n\nCity of Brussels\n\nAuthority file\n\n: Q21557453\nVIAF:\u2009158671009\nLCCN:\u2009no2007070950\nBNF:\u200915346099j\nRKD:\u2009417254\nWorldCat\n\n\n\ncreator QS:P170,Q21557453\n\n\nOther versions\n\n\n\n\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 22 cm (8.6 in); width: 32 cm (12.5 in)dimensions QS:P2048,22U174728dimensions QS:P2049,32U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nSMEETON TILLY\n\n\nOriginal captionInfoFieldEntrée de Léopold\xa0II à Bruxelles le 17 décembre 1865. Vue prise de la place de la Monnaie.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 19/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Arriv%C3%A9e_de_Maximilien_et_Charlotte_au_Vatican_le_19_avril_1864.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Arriv%C3%A9e_de_Maximilien_et_Charlotte_au_Vatican_le_19_avril_1864.jpg/640px-Arriv%C3%A9e_de_Maximilien_et_Charlotte_au_Vatican_le_19_avril_1864.jpg', 'og:image:width': '640', 'og:image:height': '892', 'og:title': 'File:Arrivée de Maximilien et Charlotte au Vatican le 19 avril 1864.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionArrivée de Maximilien et Charlotte au Vatican le 19 avril 1864.jpg\n\nFrançais\xa0:  Arrivée de l’empereur Maximilien et de l’impératrice Charlotte au Vatican, le 19 avril 1864.\n\n\nDate\n\n1864\n\n\nSource\n\nL’Illustration (France), 7 May 1864, p.293\n\n\nAuthor\n\ndrawer: \n\n\n\nAnge Louis Janet\n\xa0(1815–1872)\xa0\xa0 \xa0\n\n\n\n\n\nAlternative names\n\nAnge-Louis Janet\n\nDescription\nFrench lithographer and painter\n\nDate of birth/death\n\n1815\n22 November 1872\xa0\n\nLocation of birth/death\n\nParis\nParis\n\nAuthority file\n\n: Q15969955\nVIAF:\u200946762742\nISNI:\u20090000000121309291\nULAN:\u2009500005093\nLCCN:\u2009n83183646\nGND:\u20091052891381\nWorldCat\n\n\n\ncreator QS:P170,Q15969955\nAfter (sketch): Zwahlen.\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 23 cm (9 in); width: 17 cm (6.6 in)dimensions QS:P2048,23U174728dimensions QS:P2049,17U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nJanet Lange\n\nSignature bottom right:  \n\nL. Dumont\n\n\nOriginal captionInfoFieldVisite de LL.\xa0MM. l’empereur et l’impératrice du Mexique à S.S. le pape. Arrivée dans la cour du Vatican. D’après un croquis de M. Zwahlen.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 20/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Arriv%C3%A9e_de_Maximilien_et_Charlotte_%C3%A0_Rome_le_18_avril_1864.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Arriv%C3%A9e_de_Maximilien_et_Charlotte_%C3%A0_Rome_le_18_avril_1864.jpg/640px-Arriv%C3%A9e_de_Maximilien_et_Charlotte_%C3%A0_Rome_le_18_avril_1864.jpg', 'og:image:width': '640', 'og:image:height': '456', 'og:title': 'File:Arrivée de Maximilien et Charlotte à Rome le 18 avril 1864.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionArrivée de Maximilien et Charlotte à Rome le 18 avril 1864.jpg\n\nFrançais\xa0:  Arrivée de l’empereur Maximilien du Mexique et de l’impératrice Charlotte à Rome, le 18 avril 1864. — Deux ministres du Vatican, Mgr de Mérode et le cardinal Antonielli, accueillent Charlotte et Maximilien à la gare de Rome, puis les conduisent au palais Marescotti où ils séjourneront pendant deux jours.\n\n\nDate\n\n1864\n\n\nSource\n\nL’Illustration (France), 7 May 1864, p.\xa0292/4.\n\n\nAuthor\n\ndrawer: \n\n\n\nJules Worms\n\xa0(1832–1924)\xa0\xa0 \xa0\n\n\n\n\n\nAlternative names\n\nJ. Worms, Jules Worms\n\nDescription\nFrench painter, engraver and illustrator\n\nDate of birth/death\n\n16 December 1832\xa0\n25 November 1924\xa0\n\nLocation of birth/death\n\nParis\nParis\n\nWork period\nfrom the late 1850s on\n\nWork location\n\nFrance\xa0\n\nAuthority file\n\n: Q1711766\nVIAF:\u200995719174\nISNI:\u2009000000008050564X\nULAN:\u2009500006304\nLCCN:\u2009n2008066142\nGND:\u20091043349561\nWorldCat\n\n\n\ncreator QS:P170,Q1711766\nAfter (sketch): Zwahlen.\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 16 cm (6.2 in); width: 22 cm (8.6 in)dimensions QS:P2048,16U174728dimensions QS:P2049,22U174728\n\nInscriptionsInfoFieldSignature bottom right:  \nWorms\n\n\nOriginal captionInfoFieldArrivée de LL.\xa0MM. l’empereur et l’impératrice du Mexique à Rome. D’après un croquis de M. Zwahlen.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 21/200
# ...
# 194/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Mausol%C3%A9e_de_la_reine_Louise-Marie_de_Belgique_%C3%A0_Ostende.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/22/Mausol%C3%A9e_de_la_reine_Louise-Marie_de_Belgique_%C3%A0_Ostende.jpg/640px-Mausol%C3%A9e_de_la_reine_Louise-Marie_de_Belgique_%C3%A0_Ostende.jpg', 'og:image:width': '640', 'og:image:height': '785', 'og:title': 'File:Mausolée de la reine Louise-Marie de Belgique à Ostende.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionMausolée de la reine Louise-Marie de Belgique à Ostende.jpg\n\nFrançais\xa0:  Mausolée de la reine Louise-Marie de Belgique, église Saints-Pierre-et-Paul à Ostende.\n\n\nDate\n\n1882\n\n\nSource\n\nEugène Van Bemmel (Collectif sous la direction de), La Belgique illustrée, tome\xa0I, Bruylant-Christophe, Bruxelles, 1882, p.\xa0358.\n\n\nAuthor\n\nVictor Dedoncker (dessin), M. Weber (gravure).\n\n\n'}
# 195/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Monument_du_roi_L%C3%A9opold_Ier_au_parc_de_Laeken_en_1880.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d1/Monument_du_roi_L%C3%A9opold_Ier_au_parc_de_Laeken_en_1880.jpg/640px-Monument_du_roi_L%C3%A9opold_Ier_au_parc_de_Laeken_en_1880.jpg', 'og:image:width': '640', 'og:image:height': '959', 'og:title': 'File:Monument du roi Léopold Ier au parc de Laeken en 1880.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionMonument du roi Léopold Ier au parc de Laeken en 1880.jpg\n\nFrançais\xa0:  Monument du roi Léopold\xa0Ier de Belgique au parc de Laeken en 1880. — Le monument du roi Léopold\xa0Ier (appelé maintenant «\xa0monument de la dynastie\xa0»), de style néo-gothique flamboyant, a été édifié en 1880 par l’architecte gantois Louis de Curte (1817-1891). Il est situé dans le parc de Laeken, face au grilles du château royal de Laeken. Ses neuf arcades surmontées de neuf pinacles (petites pyramides ajourées) symbolisent l’unité des neuf provinces et celle de la Belgique derrière son roi. Chaque province a son effigie sculptée par un artiste connu de l’époque. La flèche culmine à 43\xa0mètres de hauteur et repose sur un massif en maçonnerie de 16\xa0mètres de profondeur. Un escalier à vis dans une cage de colonnette permet l’accès aux étages. Il est toutefois fermé au public. Sur la gravure, on peut apercevoir au sommet de la flèche la statue en cuivre d’un ange. La statue ne pouvant résister aux intempéries, elle a été retirée et placée sur l’une des ailes du Musée des Beaux-Arts de Bruxelles.\n\n\nDate\n\n1880\n\n\nSource\n\nL’Illustration nationale (Belgium), January 1880, p.\xa05.\n\n\nAuthor\n\ndrawer: Armand Heins.engraver: \n\n\n\nFrançois Pannemaker\n\xa0(1822–1900)\xa0\xa0\xa0 \xa0\n\n\nAlternative names\n\nAdolphe-François Pannemaker\n\nDescription\nBelgian engraver and visual artist\n\nDate of birth/death\n\n30 July 1822\xa0\n9 February 1900\xa0\n\nLocation of birth/death\n\nBrussels metropolitan area\nParis\n\nWork location\n\nCity of Brussels (1836–1843); Paris (1855–1900); City of Brussels (1845–1855); Paris (1843–1845); Paris (1861)\xa0\n\nAuthority file\n\n: Q3085503\nVIAF:\u2009288761467\nISNI:\u20090000000394340948\nULAN:\u2009500049561\nLCCN:\u2009nr90027015\nGND:\u2009129803677\nWorldCat\n\n\n\ncreator QS:P170,Q3085503\n\n\nOther versions\n\n\n\n\n\n\n\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 30 cm (11.8 in); width: 20 cm (7.8 in)dimensions QS:P2048,30U174728dimensions QS:P2049,20U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nPAN\n\nSignature bottom right:  \n\nA Heins\n\n\nOriginal captionInfoFieldLe monument de Léopold\xa0Ier au parc de Laeken. D’après les dessins de l’architecte, M. de Curte.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 196/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Monument_%C3%A9lev%C3%A9_%C3%A0_Franz_Schubert_%C3%A0_Vienne.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Monument_%C3%A9lev%C3%A9_%C3%A0_Franz_Schubert_%C3%A0_Vienne.jpg/640px-Monument_%C3%A9lev%C3%A9_%C3%A0_Franz_Schubert_%C3%A0_Vienne.jpg', 'og:image:width': '640', 'og:image:height': '731', 'og:title': 'File:Monument élevé à Franz Schubert à Vienne.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionMonument élevé à Franz Schubert à Vienne.jpg\n\nFrançais\xa0:  Monument élevé à Franz Schubert à Vienne.\n\n\nDate\n\n1880\n\n\nSource\n\nL’Illustration nationale, 1880.\n\n\nAuthor\n\nUnknown authorUnknown author\n\n\n'}
# 197/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Mort_de_la_reine_Louise-Marie_le_11_octobre_1850.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Mort_de_la_reine_Louise-Marie_le_11_octobre_1850.jpg/640px-Mort_de_la_reine_Louise-Marie_le_11_octobre_1850.jpg', 'og:image:width': '640', 'og:image:height': '326', 'og:title': 'File:Mort de la reine Louise-Marie le 11 octobre 1850.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': '\n\n\nDescriptionMort de la reine Louise-Marie le 11 octobre 1850.jpg\n\nFrançais\xa0:  Mort de la reine Louise-Marie de Belgique, Ostende, le 11 octobre 1850. — À genoux, on aperçoit de gauche à droite\xa0: le roi Léopold\xa0Ier, les trois enfants du couple\xa0: Charlotte, Léopold et Philippe. La mère de Louise, la reine Marie-Amélie, lui tient la main gauche. Son père, le roi Louis-Philippe, est mort en exil en Angleterre seulement deux mois plus tôt, le 26 août 1850.\n\n\nDate\n\n1868\n\n\nSource\n\nThéodore Juste, Histoire de Belgique, tome\xa0III, Bruylant-Christophe, Bruxelles, 1868, p.\xa0267.\n\n\nAuthor\n\ndrawer: \n\n\n\nEugène Verdyen\n\xa0(1836–1903)\xa0\xa0 \xa0\n\n\nAlternative names\n\nEugène Verdijen\n\nDescription\nBelgian painter and drawer\n\nDate of birth/death\n\n29 August 1836\xa0\n17 June 1903\xa0\n\nLocation of birth/death\n\nLiège\nCity of Brussels\n\nAuthority file\n\n: Q26235979\nVIAF:\u200996356968\nULAN:\u2009500092395\nLCCN:\u2009no2017155663\nGND:\u20091137839317\nSUDOC:\u2009203177894\nWorldCat\n\n\n\ncreator QS:P170,Q26235979\nengraver: William Brown.\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 6 cm (2.3 in); width: 12 cm (4.7 in)dimensions QS:P2048,6U174728dimensions QS:P2049,12U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nVERDYEN\n\nSignature bottom right:  \n\nW BROWN\n\n\nOriginal captionInfoFieldMort, à Ostende, de Louise d’Orléans, reine des Belges (11 octobre 1850).\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n'}
# 198/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Mort_du_roi_L%C3%A9opold_Ier_de_Belgique_le_10_d%C3%A9cembre_1865_-_Janet.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Mort_du_roi_L%C3%A9opold_Ier_de_Belgique_le_10_d%C3%A9cembre_1865_-_Janet.jpg/640px-Mort_du_roi_L%C3%A9opold_Ier_de_Belgique_le_10_d%C3%A9cembre_1865_-_Janet.jpg', 'og:image:width': '640', 'og:image:height': '447', 'og:title': 'File:Mort du roi Léopold Ier de Belgique le 10 décembre 1865 - Janet.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': "\n\n\nDescriptionMort du roi Léopold Ier de Belgique le 10 décembre 1865 - Janet.jpg\n\nFrançais\xa0:  Mort du roi Léopold\xa0Ier de Belgique, château de Laeken, le 10 décembre 1865. — Mort du roi Léopold\xa0Ier, à l’âge de 75\xa0ans et après 34\xa0ans de règne, le dimanche 10 décembre 1865 à 11 heures 45. Le Roi s’était retiré depuis quelques jours dans la petite chambre des Gobelins, au rez-de-chaussée de l’aile gauche du château de Laeken. Sont présents, ses enfants\xa0: Léopold, duc de Brabant, et bientôt roi, Marie-Henriette, duchesse de Brabant, et bientôt reine, Philippe, comte de Flandre\xa0; ses petits-enfants\xa0: la princesse Louise et le prince Léopold, comte de Hainaut, et bientôt duc de Brabant\xa0; les présidents du Sénat et de la Chambre et les ministres\xa0; Jules Van Praet, ministre de la Maison du Roi et son plus vieil ami en Belgique, le vicomte de Conway, intendant de la Liste civile, le pasteur Becker, chapelain du Roi.\n\n\nDate\n\n1865\n\n\nSource\n\nLe Monde illustré (France), 23 December 1865, p.\xa0401/1.\n\n\nAuthor\n\ndrawer: \n\n\n\nGustave Janet\n\xa0(1829–1898)\xa0\xa0 \xa0\n\n\n\n\n\nAlternative names\n\nJanet\n\nDescription\nFrench drawer\n\nDate of birth/death\n\n10 January 1829\xa0\n2 April 1898\xa0\n\nLocation of birth/death\n\nformer 10th arrondissement of Paris\nUnknown\n\nAuthority file\n\n: Q18508256\nVIAF:\u200991524218\nISNI:\u20090000000109241714\nULAN:\u2009500148102\nLCCN:\u2009nr92026023\nNLA:\u200935115829\nWorldCat\n\n\n\ncreator QS:P170,Q18508256\nengraver: \n\n\n\nCharles Maurand\n\xa0(1824–1904)\xa0\xa0 \xa0\n\n\nDescription\nFrench engraver\n\nDate of birth/death\n\n3 April 1824\xa0\n25 June 1904\xa0\n\nLocation of birth\n\nParis\n\n\nWork period\n1842\xa0–1889\xa0\n\nWork location\n\nParis\xa0\n\nAuthority file\n\n: Q15406983\nVIAF:\u20092740029\nISNI:\u20090000000008888340\nSUDOC:\u2009113579438\nBNF:\u2009149573313\nNLP:\u2009a0000003649703\n\n\n\ncreator QS:P170,Q15406983\n (photo): \n\n\n\nGhémar Frères studio\n\xa0(fl. 1882)\xa0\xa0 \xa0\n\n\nAlternative names\n\nGhemar Frères Atelier de Photographie\n\nDescription\nBelgianGhémar Frères, Photographes du Roi, 27, Rue de l'Ecuyer, Bruxelles.\nEnglish:  The photo studio of the two brothers Ghémar was the most renowned Belgian photostudio in the period 1855–1870. \nIn 1855 Louis Ghémar (1820–1873)[1] opened a photostudio in Brussels, next to the studio of Jules Géruzet. \nIn the beginning Louis Ghémar worked together with Robert Sévérin. Sévérin took the photos and Ghémar made the retouches and eventually colours the photos. But Sévérin left Brussels and was replaced by Louis Ghémars halfbrother, Léon Auverlaux. From then on the name of the studio was changed to Ghémar Frères. \n\nLouis Ghémar died in 1873 but the studio kept the name Ghémar Frères until 1894 when Géruzet takes over the studio, including all the negatives of Ghémar.[2]\n\nWork period\nbetween 1855 and 1894date QS:P,+1850-00-00T00:00:00Z/7,P1319,+1855-00-00T00:00:00Z/9,P1326,+1894-00-00T00:00:00Z/9\n\nWork location\n\nCity of Brussels\n\nAuthority file\n\n: Q21557453\nVIAF:\u2009158671009\nLCCN:\u2009no2007070950\nBNF:\u200915346099j\nRKD:\u2009417254\nWorldCat\n\n\n\ncreator QS:P170,Q21557453\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 16 cm (6.2 in); width: 23 cm (9 in)dimensions QS:P2048,16U174728dimensions QS:P2049,23U174728\n\nInscriptionsInfoFieldSignature bottom left:  \n ...
# 199/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Mort_du_roi_L%C3%A9opold_Ier_de_Belgique_le_10_d%C3%A9cembre_1865.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0f/Mort_du_roi_L%C3%A9opold_Ier_de_Belgique_le_10_d%C3%A9cembre_1865.jpg/640px-Mort_du_roi_L%C3%A9opold_Ier_de_Belgique_le_10_d%C3%A9cembre_1865.jpg', 'og:image:width': '640', 'og:image:height': '406', 'og:title': 'File:Mort du roi Léopold Ier de Belgique le 10 décembre 1865.jpg - Wikimedia Commons', 'og:type': 'website'}, 'text': "\n\n\nDescriptionMort du roi Léopold Ier de Belgique le 10 décembre 1865.jpg\n\nFrançais\xa0:  Mort du roi Léopold\xa0Ier de Belgique, château de Laeken, le 10 décembre 1865.\n\n\nDate\n\n1868\n\n\nSource\n\nThéodore Juste, Histoire de Belgique, tome\xa0III, Bruylant-Christophe, Bruxelles, 1868, p.\xa0314.\n\n\nAuthor\n\ndrawer: \n\n\n\nEugène Verdyen\n\xa0(1836–1903)\xa0\xa0 \xa0\n\n\nAlternative names\n\nEugène Verdijen\n\nDescription\nBelgian painter and drawer\n\nDate of birth/death\n\n29 August 1836\xa0\n17 June 1903\xa0\n\nLocation of birth/death\n\nLiège\nCity of Brussels\n\nAuthority file\n\n: Q26235979\nVIAF:\u200996356968\nULAN:\u2009500092395\nLCCN:\u2009no2017155663\nGND:\u20091137839317\nSUDOC:\u2009203177894\nWorldCat\n\n\n\ncreator QS:P170,Q26235979engraver: Ch. Rod. (photo): \n\n\n\nGhémar Frères studio\n\xa0(fl. 1882)\xa0\xa0 \xa0\n\n\nAlternative names\n\nGhemar Frères Atelier de Photographie\n\nDescription\nBelgianGhémar Frères, Photographes du Roi, 27, Rue de l'Ecuyer, Bruxelles.\nEnglish:  The photo studio of the two brothers Ghémar was the most renowned Belgian photostudio in the period 1855–1870. \nIn 1855 Louis Ghémar (1820–1873)[1] opened a photostudio in Brussels, next to the studio of Jules Géruzet. \nIn the beginning Louis Ghémar worked together with Robert Sévérin. Sévérin took the photos and Ghémar made the retouches and eventually colours the photos. But Sévérin left Brussels and was replaced by Louis Ghémars halfbrother, Léon Auverlaux. From then on the name of the studio was changed to Ghémar Frères. \n\nLouis Ghémar died in 1873 but the studio kept the name Ghémar Frères until 1894 when Géruzet takes over the studio, including all the negatives of Ghémar.[2]\n\nWork period\nbetween 1855 and 1894date QS:P,+1850-00-00T00:00:00Z/7,P1319,+1855-00-00T00:00:00Z/9,P1326,+1894-00-00T00:00:00Z/9\n\nWork location\n\nCity of Brussels\n\nAuthority file\n\n: Q21557453\nVIAF:\u2009158671009\nLCCN:\u2009no2007070950\nBNF:\u200915346099j\nRKD:\u2009417254\nWorldCat\n\n\n\ncreator QS:P170,Q21557453\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 7 cm (2.7 in); width: 12 cm (4.7 in)dimensions QS:P2048,7U174728dimensions QS:P2049,12U174728\n\nInscriptionsInfoFieldSignature bottom left:  \nVERDYEN\n\nSignature bottom right:  \n\nCH. ROD\n\n\nOriginal captionInfoFieldMort de Léopold\xa0Ier (10 décembre 1865).\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}
# 200/200
# {'url': 'https://commons.wikimedia.org/wiki/File:Noces_d%27argent_du_roi_L%C3%A9opold_II_et_de_la_reine_Marie-Henriette_en_1878_-_Cath%C3%A9drale.jpg', 'metadata': {'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/96/Noces_d%27argent_du_roi_L%C3%A9opold_II_et_de_la_reine_Marie-Henriette_en_1878_-_Cath%C3%A9drale.jpg/640px-Noces_d%27argent_du_roi_L%C3%A9opold_II_et_de_la_reine_Marie-Henriette_en_1878_-_Cath%C3%A9drale.jpg', 'og:image:width': '640', 'og:image:height': '441', 'og:title': "File:Noces d'argent du roi Léopold II et de la reine Marie-Henriette en 1878 - Cathédrale.jpg - Wikimedia Commons", 'og:type': 'website'}, 'text': "\n\n\nDescriptionNoces d'argent du roi Léopold II et de la reine Marie-Henriette en 1878 - Cathédrale.jpg\n\nFrançais\xa0:  Noces d’argent du roi Léopold\xa0II de Belgique et de la reine Marie-Henriette, Cathédrale Saints-Michel-et-Gudule (Bruxelles), le 22 août 1878.\n\n\nDate\n\n1878\n\n\nSource\n\nLe Monde illustré (France), 7 September 1878, p.\xa0149.\n\n\nAuthor\n\n\n\n\n\nHenri Louis Scott\n\xa0(1846–1884)\xa0\xa0 \xa0\n\n\n\n\n\nAlternative names\n\nScott; H. Scott; Henry Scott (1849-1884); Henry Scott; Henry Louis Scott\n\nDescription\nprintmaker, illustrator and scenographer\n\nDate of birth/death\n\n8 April 1846\xa0\nMay 1884\xa0\n\nLocation of birth/death\n\nLe Havre\nParis\n\nWork location\n\nParis (1872–1879)\xa0\n\nAuthority file\n\n: Q61692855\nVIAF:\u200914869267\nISNI:\u20090000000117454277\nULAN:\u2009500097110\nSUDOC:\u2009137397291\nBNF:\u2009124611524\n\n\n\ncreator QS:P170,Q61692855\ndrawer: M. Scott.After (sketch): Walker.\n\nTechniqueInfoFieldwood engraving print\n\nSizeInfoFieldheight: 22 cm (8.6 in); width: 31 cm (12.2 in)dimensions QS:P2048,22U174728dimensions QS:P2049,31U174728\n\nInscriptionsInfoFieldSignature bottom right:  \nM. Scott\n\n\nOriginal captionInfoFieldBruxelles. Les noces d’argent. Le roi et la reine sortant de la cathédrale de Sainte Gudule après le Te Deum. Dessin de M. Scott, d’après le croquis de Walker.\n\nScanned byInfoFieldÉric Dodémont (Dodeeric)\n\n\n"}

# %%
# Open the JSON file to check its content (will produce an error if it's not a correctly formated JSON file)
with open(f"{file_path}-swp.json", "r") as input_file:
    items_read = json.load(input_file)

# %% [markdown]
# ## Index

# %%
# Open the JSON files and load each JSON item one by one in the "documents" variable (type: Document)

file_path1 = "/content/drive/MyDrive/colab/commons-urls-ds1-swp.json"
file_path2 = "/content/drive/MyDrive/colab/balat-urls-ds1-swp.json"
file_path3 = "/content/drive/MyDrive/colab/belgica-urls-ds1-swp.json"
file_path4 = "/content/drive/MyDrive/colab/commons-urls-ds2-swp.json"
file_path5 = "/content/drive/MyDrive/colab/balat-urls-ds2-swp.json"
file_paths = [file_path1, file_path2, file_path3, file_path4, file_path5]

documents = []
for file_path in file_paths:
    loader = JSONLoader(file_path=file_path, jq_schema=".[]", text_content=False)
    docs = loader.load() # Chunks (JSON items) from the JSON files; list of Documents
    documents = documents + docs # This variable contents all the JSON items

# %%
# Open the PDF files and load each page one by one in the "documents" variable (type: Document)

file_path1 = "/content/drive/MyDrive/colab/cdf-fxw.pdf"
file_paths = [file_path1]

for file_path in file_paths:
    loader = PyPDFLoader(file_path)
    pages = loader.load_and_split() # 1 pdf page per chunk
    documents = documents + pages

# %% [markdown]
# Run step 1 or step 2:

# %%
# STEP 1: Instanciate a Chroma DB and load the data from disk.
collection_name = "bmae"
embedding_model = OpenAIEmbeddings(model="text-embedding-3-large") # 3072 dimensions vectors used to embed the chunks and the questions
vector_db = Chroma(embedding_function=embedding_model, collection_name=collection_name, persist_directory="/content/drive/MyDrive/colab/chromadb")

# %%
# STEP 2: ONLY TO EMBED! Instantiate a Chroma DB, embed the JSON items (documents), then save to disk.
collection_name = "bmae"
embedding_model = OpenAIEmbeddings(model="text-embedding-3-large") # 3072 dimensions vectors used to embed the chunks and the questions
vector_db = Chroma.from_documents(documents, embedding_model, collection_name=collection_name, persist_directory="/content/drive/MyDrive/colab/chromadb")
# To check the Chroma vector db (sqlite3):
# $ sqlite3 chroma.sqlite3
# sqlite> .tables ===> List of the tables
# sqlite> select * from collections; ===> Name of the collection & size of the vectors
# sqlite> select * from embeddings; ===> Number of records in the db
# sqlite> select * from embedding_metadata; ===> Display json items

# %% [markdown]
# ## Retrieve and generate

# %%
# LLM chatbot with a hybrid RAG chain:
# (To embed the question, the same model is used as for the data; the model is given in "vector_db".)

llm = ChatOpenAI(model="gpt-4-turbo-2024-04-09", temperature=0)

# Semantic search (vector retriever)
vector_retriever = vector_db.as_retriever(search_type="similarity", search_kwargs={"k": 3}) # Chroma DB

# Keyword search (bm25 retriever)
keyword_retriever = BM25Retriever.from_documents(documents)
keyword_retriever.k = 3

# Ensemble retriever (mix of both retrivers) -- Weights = order of the results!!! [1,0] means: all bm25 first, all vector after...
ensemble_retriever = EnsembleRetriever(retrievers=[keyword_retriever, vector_retriever], weights=[0.5, 0.5])

"""
# Without memory:

# Download prompt template: system prompt + inputs (rag_output + chat_history + question)
prompt = hub.pull("dodeeric/rag-prompt-bmae-with-history")

# Take the text content of each doc, and concatenate them in one string to pass to the prompt (context)
def format_docs_clear_text(docs):
    return "\n\n".join(doc.page_content.encode('utf-8').decode('unicode_escape') for doc in docs)

# Function to display the text content of the prompt in ai_assistant_chain
def print_and_pass(data):
    print(f"Prompt content sent to the LLM: {data}")
    return data

# Langchain chain: the LLM chatbot with hybrid RAG. Type: RunnableSequence (chain) -- How/where is the question pass to the RAG??? In LangSmith, we can see the input (question) of the 3 retreivers
ai_assistant_chain = ({"rag_output": ensemble_retriever | format_docs_clear_text, "chat_history": RunnablePassthrough(), "question": RunnablePassthrough()}
    | prompt
    #| print_and_pass
    | llm
    | StrOutputParser() # Convert to string
)
"""

from langchain.chains import create_history_aware_retriever
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.messages import HumanMessage, AIMessage

from langchain.memory import ConversationBufferWindowMemory

chat_history = []
chat_history2 = ConversationBufferWindowMemory(k=2, return_messages=True)

contextualize_q_system_prompt = """
Given a chat history and the latest user question \
which might reference context in the chat history, formulate a standalone question \
which can be understood without the chat history. Do NOT answer the question, \
just reformulate it if needed and otherwise return it as is.
"""

contextualize_q_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", contextualize_q_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)

history_aware_retriever = create_history_aware_retriever(
    llm, ensemble_retriever, contextualize_q_prompt
)

qa_system_prompt = """
You are an artwork specialist. You must assist the users in finding, describing, and displaying artworks related to the Belgian monarchy. \
You first have to search answers in the "Knowledge Base". If no answers are found in the "Knowledge Base", then answer with your own knowledge. \
You have to answer in the same language as the question.
At the end of the answer:
- give a link to a web page about the artwork (see the "url" field).
- display an image of the artwork (see the "og:image" field).

Knowledge Base:

{context}
"""

qa_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", qa_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)

question_answer_chain = create_stuff_documents_chain(llm, qa_prompt)

ai_assistant_chain = create_retrieval_chain(history_aware_retriever, question_answer_chain)

# %% [markdown]
# Query the AI Assistant:

# %%
question = "Pouvez-vous me montrer le tableau 'La revue des écoles' ?"

# %%
question = "Qui a peint ce tableau ?"

# %%
question = "Quelle est la dimension du tableau ?"

# %%
question = "Pouvez-vous me montrer un tableau de Charles Porion ?"

# %%
question = "Quel est la date de naissance du peintre ?"

# %%
question = "Camille Van Camp a-t-il fait des croquis pour sa peinture 'La fête patriotique ' ?"

# %%
#answer = ai_assistant_chain.invoke(question) # Without memory

# %%
output = ai_assistant_chain.invoke({"input": question, "chat_history": chat_history}) # output is a dictionary. output["answer"] is in markdown format.

# %%
print(output["answer"])
# Out:
# Le tableau "La revue des écoles en 1878" de Jan Verhas mesure 241 cm de hauteur et 432 cm de largeur. Cette grande toile monumentale est exposée aux Musées royaux des Beaux-Arts de Belgique.

# %%
#chat_history.extend([HumanMessage(content=question), output["answer"]])

# %%
#chat_history.extend([question, output["answer"]])

# %%
chat_history2.save_context({"input": question}, {"output": output["answer"]})

# %%
load_memory = chat_history2.load_memory_variables({})

# %%
chat_history = load_memory["history"]

# %%
print(chat_history)
# Out:
# [HumanMessage(content="Pouvez-vous me montrer le tableau 'La revue des écoles' ?"), AIMessage(content='Le tableau "La revue des écoles en 1878" de Jan Verhas est une œuvre importante qui capture un événement marquant de l\'histoire belge. Réalisée en 1880, cette peinture illustre le défilé de 23.000 élèves des écoles bruxelloises devant le roi Léopold II et la reine Marie-Henriette à l\'occasion de leurs noces d\'argent. L\'événement a eu lieu le 22 août 1878 sur la place des Palais à Bruxelles. Cette œuvre est célèbre pour sa représentation détaillée et vivante de la parade, mettant en avant l\'importance de l\'éducation et la jeunesse dans la société belge de l\'époque.\n\nPour plus d\'informations sur ce tableau, vous pouvez visiter la page suivante : [La revue des écoles en 1878](https://commons.wikimedia.org/wiki/File:Jan_Verhas_(1834-1896)_Optocht_van_de_scholen_in_1878_-_Old_Masters_Museum_Brussel_30-4-2017_11-18-20.JPG)\n\n![La revue des écoles en 1878](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Jan_Verhas_%281834-1896%29_Optocht_van_de_scholen_in_1878_-_Old_Masters_Museum_Brussel_30-4-2017_11-18-20.JPG/640px-Jan_Verhas_%281834-1896%29_Optocht_van_de_scholen_in_1878_-_Old_Masters_Museum_Brussel_30-4-2017_11-18-20.JPG)'), HumanMessage(content='Qui a peint ce tableau ?'), AIMessage(content='Le tableau "La revue des écoles en 1878" a été peint par Jan Verhas, un peintre belge né en 1834 et décédé en 1896. Jan Verhas était spécialisé dans la peinture de genre et est connu pour ses représentations détaillées de la vie sociale et des événements importants en Belgique. Son œuvre "La revue des écoles en 1878" est particulièrement célèbre pour sa représentation vivante et détaillée d\'un événement marquant impliquant la monarchie belge.\n\nPour plus d\'informations sur ce tableau, vous pouvez visiter la page suivante : [La revue des écoles en 1878](https://commons.wikimedia.org/wiki/File:Jan_Verhas_(1834-1896)_Optocht_van_de_scholen_in_1878_-_Old_Masters_Museum_Brussel_30-4-2017_11-18-20.JPG)\n\n![La revue des écoles en 1878](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Jan_Verhas_%281834-1896%29_Optocht_van_de_scholen_in_1878_-_Old_Masters_Museum_Brussel_30-4-2017_11-18-20.JPG/640px-Jan_Verhas_%281834-1896%29_Optocht_van_de_scholen_in_1878_-_Old_Masters_Museum_Brussel_30-4-2017_11-18-20.JPG)')]

# %%
chat_history3

# %%
# Query the vector RAG only
docs = vector_db.similarity_search(question, k=2) # List of Documents; page_content of a Document: string
print(docs)

# %% [markdown]
# Tests
